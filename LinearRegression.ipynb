# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("linear_regression_dataset.csv")

# %%
def gradient_descent(m_now,b_now,points,L):
    m_gradient=0
    b_gradient=0
    n=len(points)
    for i in range(n):
        x=points.iloc[i].X
        y=points.iloc[i].Y
        m_gradient+=-(2/n)*x*(y-(m_now*x+b_now))
        b_gradient+=-(2/n)*(y-(m_now * x * +b_now))
    m=m_now-m_gradient * L
    b=b_now-b_gradient * L
    return m,b

# %%
m=0
b=0
L=0.0001
epochs=300
for i in range(epochs):
    m,b=gradient_descent(m,b,data,L)

# %%
m
# Out:
# 3.759790851801129

# %%
b
# Out:
# 1.0389279347315366

# %%
x_range=range(int(data["X"].min()),int(data["X"].max()))

# %%
plt.scatter(data.X, data.Y, color="black")

plt.plot(list(x_range),[m*x + b for x in x_range],
    color="red"
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 2
#       1 plt.scatter(data.X,data.Y,color="Black")
# ----> 2 plt.plot(list(x_range,[m*x+b for x in X_range],color="red"))
#
# NameError: name 'X_range' is not defined
